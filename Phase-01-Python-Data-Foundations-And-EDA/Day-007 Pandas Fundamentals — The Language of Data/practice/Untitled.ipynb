# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "Name": ["Aditya", "Rahul", "Priya"],
    "Age": [28, 32, 25],
    "Salary": [100000, 120000, 90000]
})

# %%
df
# Out:
#      Name  Age  Salary
# 0  Aditya   28  100000
# 1   Rahul   32  120000
# 2   Priya   25   90000

# %%
df['Salary']
# Out:
# 0    100000
# 1    120000
# 2     90000
# Name: Salary, dtype: int64

# %%
df[['Age','Salary']]
# Out:
#    Age  Salary
# 0   28  100000
# 1   32  120000
# 2   25   90000

# %%
df['Age'] > 30
# Out:
# 0    False
# 1     True
# 2    False
# Name: Age, dtype: bool

# %%
df[df['Age'] > 30]
# Out:
#     Name  Age  Salary
# 1  Rahul   32  120000

# %%
df.sort_values(
    by="Salary",
    ascending=False
)
# Out:
#      Name  Age  Salary
# 1   Rahul   32  120000
# 0  Aditya   28  100000
# 2   Priya   25   90000

# %%
df["Salary"].mean()
# Out:
# np.float64(103333.33333333333)

# %%
df["Salary"].max()
# Out:
# np.int64(120000)

# %%
df["Salary"].min()
# Out:
# np.int64(90000)

# %%
df.groupby("Department")[
    "Salary"
].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.groupby("Department")[
#       2     "Salary"
#       3 ].mean()
#
# File ~/AI/.venv/lib/python3.10/site-packages/pandas/core/frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# ...
